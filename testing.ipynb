# %%
import pandas as pd

# %%
df = pd.read_csv("data/cleaned_data.csv", index_col="NPA")
df
# Out:
#      Area-2020  Age_of_Residents-2021  Tree_Canopy-2012  \
# NPA
# 2    -0.418097              -0.858584          0.599348
# 3     0.557507              -0.588272         -0.513685
# 5    -0.736605              -0.601787         -0.498335
# 8    -0.174753              -0.412568          0.884178
# 11   -0.287860               0.222666          0.587273
# ..         ...                    ...               ...
# 387   1.378521              -0.182803         -0.899308
# 389   0.483682              -0.453115          0.257811
# 392   0.963964               0.492979          1.161400
# 393   0.350760              -0.858584          0.079048
# 394  -0.441642              -0.047646          0.635654
#
#      Impervious_Surface-2023  Housing_Density-2023  Housing_Size-2023  \
# NPA
# 2                   0.326066              0.157465          -0.586356
# 3                   1.860837              2.768740           0.807002
# ...

# %%
rows_missing = df.isnull()
rows_missing
